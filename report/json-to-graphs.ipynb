# %%
import json

with open('/home/ron/Downloads/tensorboard/runs_Apr06_22-18-55_evc7 (1).json','r') as file:
    data = json.load(file)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plotgraphs(data, ylab):
    data = np.array(data)
    # print(data)
    # print(data[:,1])

    # for _, x, y in data:
    plt.plot(data[:,1],data[:,2],'-',c='b')
    plt.xlabel('Epoch')
    plt.ylabel(ylab)
    plt.show()

plotgraphs(data, 'Cross-Entropy Loss')

# %%
with open('/home/ron/Downloads/tensorboard/runs_Apr06_22-18-55_evc7.json','r') as file:
    data1 = json.load(file)
    
plotgraphs(data1,'Arcface Loss')

# %%
with open('/home/ron/Downloads/tensorboard/runs_Apr06_22-18-55_evc7 (2).json','r') as file:
    data1 = json.load(file)
    
plotgraphs(data1,'Contrastive Loss')

# %%
with open('/home/ron/Downloads/tensorboard/runs_Apr06_22-18-55_evc7 (3).json','r') as file:
    data1 = json.load(file)
    
plotgraphs(data1,'Overall Loss')

# %%
with open('/home/ron/Downloads/tensorboard/runs_Apr06_22-18-55_evc7 (4).json','r') as file:
    data1 = json.load(file)
    
plotgraphs(data1,'Metric Loss')

# %%
with open('/home/ron/Downloads/tensorboard/runs_Apr06_22-18-55_evc7 (5).json','r') as file:
    data1 = json.load(file)
    
plotgraphs(data1,'Triplet Loss')
